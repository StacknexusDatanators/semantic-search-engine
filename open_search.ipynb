# %%
from opensearchpy import OpenSearch
from elasticsearch.helpers import bulk
import json
from opensearchpy import OpenSearch, RequestsHttpConnection, AWSV4SignerAuth
import pandas as pd
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('all-MiniLM-L6-v2')

# %%
host = 'localhost'
port = 9200
auth = ('admin', 'admin') # For testing only. Don't store credentials in code.
#ca_certs_path = '/full/path/to/root-ca.pem' # Provide a CA bundle if you use intermediate CAs with your root CA.

# Create the client with SSL/TLS enabled, but hostname verification disabled.
client = OpenSearch(
    hosts = [{'host': host, 'port': port}],
    http_compress = True, # enables gzip compression for request bodies
    http_auth = auth,
    use_ssl = True,
    verify_certs = False,
    ssl_assert_hostname = False,
    ssl_show_warn = False,
)

# %%
with open("Retail_DP_Sample.json") as f:
    doc = json.load(f)

# %%
doc.keys()
# Out:
# dict_keys(['title', 'owner', 'tier', 'version', 'version_date', 'description', 'tags', 'Health', 'governance', 'stacks', 'document', 'data_sources'])

# %%
doc
# Out:
# {'title': 'Customer_360',
#  'owner': 'Ishmin Singh',
#  'tier': 'Gold',
#  'version': 'v1.1',
#  'version_date': 'July 17, 2023 13:00',
#  'description': 'Customer data from various sources, enabling a holistic view of customers. ',
#  'tags': ['marketing', 'customer.360'],
#  'Health': {'quality_score': '70%', 'operational_health': '70%'},
#  'governance': {'access_policies': 3, 'data_policies': 3},
#  'stacks': ['flare', 'benthos', 'alpha'],
#  'document': 'What is it?\nThe Customer 360 is a tool designed to create a comprehensive view of customers by combining data from multiple sources. It includes information centered around a customer and further associated details of stores, products, and transaction details. \n\nWhat does it solve? \nCustomer 360 addresses the challenge of aggregating and analyzing customer-related data from disparate sources. By consolidating data into a unified format, it enables users to gain valuable insights into customer behavior, purchase patterns, and preferences. This comprehensive view empowers teams to make data-driven decisions. \nUse Cases \n• Customer Analytics: Businesses can gain insights into customer behavior, identify high-value customers, and personalize marketing strategies. \n• Inventory Management: By understanding product preferences and demand patterns, companies can optimize their inventory and restocking processes.\n• Fraud Detection: Analyzing customer orders and transaction data can help identify suspicious activities or potential fraud.\n• Personalization Opportunities: By understanding individual customer preferences and purchase habits, businesses can personalize marketing efforts, promotions, and product recommendations, enhancing customer satisfaction and loyalty. \n• Demand and Inventory Insights: Analyzing purchase patterns can provide valuable insights into demand for specific products or services, enabling businesses to optimize inventory management and restocking strategies. \n• Event-Driven Marketing: Businesses can leverage streaming data to trigger event-driven marketing campaigns. For example, sending personalized offers or promotions based on specific customer actions, such as completing a large purchase. \n\nKey Features \n• Advanced analytics\n Built with \n\nWhat libraries and frameworks does it use? \n• Python: For data processing, transformation, and integration tasks. \nApache Kafka: To enable real-time streaming of customer order events. \nApache Spark: For handling large-scale data processing efficiently. \nPostgreSQL: As the primary database to store the enriched order data. ',
#  'data_sources': [{'title': 'customers',
#    'description': 'Contains customer information, including customer_index, name, contact details, and other relevant attributes. '},
#   {'title': 'stores',
#    'description': 'Provides data about various stores, including store_index, location, and store attributes.'},
#   {'title': 'products',
#    'description': 'Contains details of different products, including product_index, name, description, and product attributes. '},
#   {'title': 'transactions',
#    'description': 'Holds transaction data, including transaction_index, transaction_date, transaction_line_item, and transaction details.'}]}

# %%
client.indices.create(index = "dp_test_1")
# Out:
# {'acknowledged': True, 'shards_acknowledged': True, 'index': 'dp_test_1'}

# %%
client.indices.delete(index = "dp_test_1")
# Out:
# {'acknowledged': True}

# %%
client.index(index = "dp_test_1", body=doc)
# Out:
# {'_index': 'dp_test_1',
#  '_id': 'hxyiQI4B8m6BE82W_4Uy',
#  '_version': 1,
#  'result': 'created',
#  '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#  '_seq_no': 0,
#  '_primary_term': 1}

# %%
with open("combined_finance.json") as f:
    doc_fin = json.load(f)

# %%
client.index(index = "dp_test_1", body=doc_fin)
# Out:
# {'_index': 'dp_test_1',
#  '_id': 'oETnm40Bt1213c7wTl7x',
#  '_version': 1,
#  'result': 'created',
#  '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#  '_seq_no': 1,
#  '_primary_term': 1}

# %%
with open("combined_health.json") as f:
    doc_hel = json.load(f)

# %%
client.index(index = "dp_test_1", body=doc_hel)
# Out:
# {'_index': 'dp_test_1',
#  '_id': 'oUTnm40Bt1213c7wU14r',
#  '_version': 1,
#  'result': 'created',
#  '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#  '_seq_no': 2,
#  '_primary_term': 1}

# %%
qr = {
  "query": {
    "match_all": {}
  },
  "size":50
}

# %%
client.search(body = qr, index = "dp_test_1")["hits"]["hits"]
# Out:
# [{'_index': 'dp_test_1',
#   '_id': 'n0Tnm40Bt1213c7wSl7s',
#   '_score': 1.0,
#   '_source': {'title': 'Customer_360',
#    'owner': 'Ishmin Singh',
#    'tier': 'Gold',
#    'version': 'v1.1',
#    'version_date': 'July 17, 2023 13:00',
#    'description': 'Customer data from various sources, enabling a holistic view of customers. ',
#    'tags': ['marketing', 'customer.360'],
#    'Health': {'quality_score': '70%', 'operational_health': '70%'},
#    'governance': {'access_policies': 3, 'data_policies': 3},
#    'stacks': ['flare', 'benthos', 'alpha'],
#    'document': 'What is it?\nThe Customer 360 is a tool designed to create a comprehensive view of customers by combining data from multiple sources. It includes information centered around a customer and further associated details of stores, products, and transaction details. \n\nWhat does it solve? \nCustomer 360 addresses the challenge of aggregating and analyzing customer-related data from disparate sources. By consolidating data into a unified format, it enables users to gain valuable insights into customer behavior, purchase patterns, and preferences. This comprehensive view empowers teams to make data-driven decisions. \nUse Cases \n• Customer Analytics: Businesses can gain insights into customer behavior, identify high-value customers, and personalize marketing strategies. \n• Inventory Management: By understanding product preferences and demand patterns, companies can optimize their inventory and restocking processes.\n• Fraud Detection: Analyzing customer orders and transaction data can help identify suspicious activities or potential fraud.\n• Personalization Opportunities: By understanding individual customer preferences and purchase habits, businesses can personalize marketing efforts, promotions, and product recommendations, enhancing customer satisfaction and loyalty. \n• Demand and Inventory Insights: Analyzing purchase patterns can provide valuable insights into demand for specific products or services, enabling businesses to optimize inventory management and restocking strategies. \n• Event-Driven Marketing: Businesses can leverage streaming data to trigger event-driven marketing campaigns. For example, sending personalized offers or promotions based on specific customer actions, such as completing a large purchase. \n\nKey Features \n• Advanced analytics\n Built with \n\nWhat libraries and frameworks does it use? \n• Python: For data processing, transformation, and integration tasks. \nApache Kafka: To enable real-time streaming of customer order events. \nApache Spark: For handling large-scale data processing efficiently. \nPostgreSQL: As the primary database to store the enriched order data. ',
#    'data_sources': [{'title': 'customers',
#      'description': 'Contains customer information, including customer_index, name, contact details, and other relevant attributes. '},
#     {'title': 'stores',
#      'description': 'Provides data about various stores, including store_index, location, and store attributes.'},
#     {'title': 'products',
#      'description': 'Contains details of different products, including product_index, name, description, and product attributes. '},
#     {'title': 'transactions',
#      'description': 'Holds transaction data, including transaction_index, transaction_date, transaction_line_item, and transaction details.'}],
#    'title_vec': [-0.0750977173447609,
#     -0.032000962644815445,
#     -0.03437187522649765,
#     -0.05432145297527313,
#     0.00916987843811512,
#     -0.04182756692171097,
#     0.10451317578554153,
#     0.009180745109915733,
#     0.017489440739154816,
#     -0.060192156583070755,
#     0.07124655693769455,
#     -0.020160838961601257,
#     0.034009117633104324,
#     -0.02023700624704361,
#     0.03482157364487648,
#     -0.02517235465347767,
#     -0.005659426096826792,
#     0.0275372713804245,
#     -0.10023247450590134,
#     0.006730087101459503,
#     -0.14080402255058289,
#     0.002083411207422614,
#     -0.06547528505325317,
#     0.05336359888315201,
#     -0.05474459007382393,
#     0.041959118098020554,
#     0.007732255384325981,
#     0.05553324893116951,
#     -0.052701305598020554,
#     -0.04416738077998161,
#     0.005193446297198534,
#     0.03232533112168312,
#     0.11941839754581451,
#     0.006203311029821634,
#     0.04273543134331703,
#     -0.02767103537917137,
#     -0.06385062634944916,
#     -0.026103733107447624,
#     -0.08253177255392075,
#     -0.010413719341158867,
#     -0.05973507836461067,
#     -0.07561729103326797,
#     -0.025324933230876923,
#     0.023954126983880997,
#     0.045533984899520874,
#     0.026585403829813004,
#     -0.006193633656948805,
#     0.03419651836156845,
#     0.08610272407531738,
#     0.052831798791885376,
#     -0.06541313230991364,
#     -0.008901803754270077,
#     -0.045873578637838364,
#     0.03369394317269325,
#     -0.04046030342578888,
#     0.003384361509233713,
#     -0.022013671696186066,
#     -0.0034824979957193136,
#     0.02943599969148636,
#     0.028087908402085304,
#     -0.009445487521588802,
#     -0.04213394969701767,
#     0.006628233473747969,
#     0.060601428151130676,
#     -0.034527283161878586,
#     -0.045289602130651474,
#     -0.1232633963227272,
#     -0.04645436629652977,
#     -0.032212745398283005,
#     -0.01945478841662407,
#     -0.06583932042121887,
#     0.035367701202631,
#     -0.0365535169839859,
#     0.04050233215093613,
#     0.030122285708785057,
#     -0.0030199873726814985,
#     0.011165168136358261,
#     -0.0034065749496221542,
#     0.05467766895890236,
#     0.012759195640683174,
#     0.016904203221201897,
#     -0.024471310898661613,
#     0.014979655854403973,
#     -0.015936998650431633,
#     -0.011816594749689102,
#     0.04519135504961014,
#     0.06613260507583618,
#     -0.014180311933159828,
#     -0.09239474684000015,
#     -0.0369686596095562,
#     0.02329675480723381,
#     0.08596732467412949,
#     0.06835771352052689,
#     -0.03375883027911186,
#     -0.17808397114276886,
#     0.014834713190793991,
#     0.05559676140546799,
#     -0.0935497060418129,
#     -0.0615859180688858,
#     0.14399489760398865,
#     -0.009316983632743359,
#     0.05131968483328819,
#     0.022069748491048813,
#     0.04044722393155098,
#     -0.028503399342298508,
#     0.0156281478703022,
#     -0.024502862244844437,
#     0.13904976844787598,
#     0.008310017175972462,
#     0.07018034905195236,
#     0.004682297818362713,
#     -0.005400128196924925,
#     0.1366249918937683,
#     0.03142514452338219,
#     -0.005414067767560482,
#     0.04848732799291611,
#     0.07839728146791458,
#     -0.1024729460477829,
#     0.0010813463013619184,
#     -0.010676710866391659,
#     0.047360122203826904,
#     -0.06681095063686371,
#     0.02816462516784668,
#     0.0020118693355470896,
#     -0.02637646161019802,
#     -0.00846742745488882,
#     -0.07234364002943039,
#     -0.027644963935017586,
#     -0.005705660209059715,
#     0.05110034719109535,
#     0.0021401802077889442,
#     0.05705586448311806,
#     0.038924138993024826,
#     0.05368576943874359,
#     0.033207062631845474,
#     0.02806105837225914,
#     -0.020477119833230972,
#     0.046933505684137344,
#     -0.03954809159040451,
#     -0.03198666498064995,
#     0.10530620813369751,
#     0.018645860254764557,
#     -0.04827269911766052,
#     -0.03126654773950577,
#     0.02367212064564228,
#     0.005961138289421797,
#     0.03254494071006775,
#     0.03606141358613968,
#     0.0517631471157074,
#     0.029919076710939407,
#     -0.04430632293224335,
#     0.00024025447783060372]}},
#  {'_index': 'dp_test_1',
#   '_id': 'oETnm40Bt1213c7wTl7x',
#   '_score': 1.0,
#   '_source': {'title': 'Banking_360',
#    'owner': 'Alexandra Mitchell',
#    'tier': 'Diamond',
#    'version': 'v2.0',
#    'version_date': 'November 15, 2023 10:45',
#    'description': 'Comprehensive banking data integration platform for a unified view of customer financial profiles and transactions.',
#    'tags': ['banking', 'financial_data', 'customer_insights'],
#    'Health': {'quality_score': '80%', 'operational_health': '85%'},
#    'governance': {'access_policies': 4, 'data_policies': 4},
#    'stacks': ['flare', 'alpha', 'benthos'],
#    'document': 'What is it?\nThe Banking 360 is a platform designed to aggregate and analyze banking-related data, providing a holistic view of customer financial profiles, transactions, and interactions. It empowers financial institutions to enhance customer experiences, optimize operations, and make data-driven decisions.\n\nWhat does it solve?\nBanking 360 addresses the challenge of managing and understanding vast amounts of banking data. By consolidating and analyzing this data, it enables banks to offer personalized services, detect fraudulent activities, and streamline operational processes.\nUse Cases\n• Customer Engagement: Provides insights into customer behavior, preferences, and financial needs, enabling personalized services and product recommendations.\n• Fraud Detection: Analyzes transaction patterns to identify and prevent fraudulent activities, ensuring the security of customer accounts.\n• Operational Efficiency: Optimizes banking processes, including loan approvals, risk assessments, and compliance checks.\n• Regulatory Compliance: Ensures adherence to banking regulations and data privacy standards.\n• Credit Risk Management: Analyzes customer credit profiles and transaction history to assess credit risk and inform lending decisions.\n\nKey Features\n• Real-time Transaction Monitoring\n• Customer Segmentation\n• Risk Analytics\n• Regulatory Reporting\n\nWhat technologies does it use?\n• Apache Kafka: Enables real-time streaming of banking events and transactions.\n• SQL Server: Relational database for secure storage of sensitive financial data.\n• Python: Utilized for data processing, analytics, and machine learning.\n• Tableau: Data visualization for actionable insights and reporting.\n',
#    'data_sources': [{'title': 'customer_accounts',
#      'description': 'Contains customer financial profiles, account balances, and transaction history.'},
#     {'title': 'transactions',
#      'description': 'Holds detailed information about banking transactions, including dates, amounts, and transaction types.'},
#     {'title': 'credit_scores',
#     -0.045836444944143295,
#     -0.03204628452658653,
#     0.09190281480550766,
#     -0.06681331247091293,
#     0.022628402337431908,
#     0.011210888624191284,
#     0.0772736668586731,
#     0.05940062552690506,
#     -0.07715253531932831,
#     0.006280458066612482,
#     -0.014153355732560158,
#     -0.050579734146595,
#     -0.013536623679101467,
#     0.03189629316329956,
#     0.01091880351305008,
#     0.027570368722081184,
#     -0.02398146688938141,
#     0.019402993842959404,
#     0.02709759585559368,
#     -0.0004574954218696803,
#     0.048180483281612396,
#     -0.030629519373178482,
#     0.12689907848834991,
#     0.06844054162502289,
#     0.0328712984919548,
#     0.009771337732672691,
#     -0.015450170263648033,
#     0.0012024601455777884,
#     0.08077896386384964,
#     -0.04725415259599686,
#     0.10204540938138962,
#     -0.011138562113046646,
#     0.01731312833726406,
#     -0.05531075596809387]}},
#  {'_index': 'dp_test_1',
#   '_id': 'oUTnm40Bt1213c7wU14r',
#   '_score': 1.0,
#   '_source': {'title': 'Healthcare_360',
#    'owner': 'Dr. Amanda Rodriguez',
#    'tier': 'Platinum',
#    'version': 'v1.0',
#    'version_date': 'October 24, 2023 09:30',
#    'description': 'Comprehensive healthcare data integration platform for a unified view of patient records and medical information.',
#    'tags': ['healthcare', 'patient_records', 'medical_data'],
#    'Health': {'quality_score': '85%', 'operational_health': '90%'},
#    'governance': {'access_policies': 4, 'data_policies': 4},
#    'stacks': ['flare', 'benthos', 'alpha'],
# ...
#     0.0031184465624392033,
#     0.06773149967193604,
#     0.040195532143116,
#     -0.08628770709037781,
#     0.11663533002138138,
#     0.0422268845140934,
#     -0.003107851603999734,
#     0.042352184653282166,
#     -0.0430893637239933,
#     -0.08139195293188095,
#     0.015601444989442825,
#     -0.03552170470356941,
#     -0.004237811081111431,
#     -0.0795101746916771,
#     -0.03132203593850136,
#     0.000999823329038918,
#     -0.04730357602238655,
#     0.0073555451817810535,
#     -0.04283574968576431,
#     -0.021533463150262833,
#     0.05923078954219818,
#     0.04430260509252548,
#     0.09346560388803482,
#     0.005265870597213507,
#     -0.03490777686238289,
#     0.02117328904569149,
#     -0.04960991442203522,
#     0.01936201937496662,
#     -0.048708461225032806,
#     -0.013097492977976799,
#     -0.01240796223282814,
#     -0.08360666036605835,
#     -0.00030846367008052766,
#     0.03319093585014343,
#     -0.023698139935731888,
#     -0.05885728448629379,
#     0.05058806762099266,
#     0.0094760125502944,
#     -0.02251693233847618,
#     -0.07002875208854675,
#     -0.0770205482840538,
#     -0.059330571442842484,
#     0.03507808595895767,
#     -0.07406831532716751,
#     0.0861268863081932,
#     0.013142609037458897,
#     -0.027973363175988197,
#     0.03225627541542053,
#     0.050095442682504654,
#     0.04877433553338051,
#     -0.014464166015386581,
#     0.043291203677654266,
#     -0.044621050357818604,
#     0.002571383025497198,
#     -0.044054608792066574,
#     0.029191428795456886,
#     -0.054827719926834106,
#     0.05188928171992302,
#     -0.04607776179909706,
#     0.03557687997817993,
#     0.05576498806476593,
#     0.013229425996541977,
#     -0.033045753836631775,
#     -0.02264675870537758,
#     -0.07762469351291656,
#     -0.05662571266293526,
#     -0.050019294023513794,
#     0.10767737030982971,
#     -0.03946228697896004,
#     0.05745071917772293,
#     -0.01815217360854149,
#     -0.026905300095677376,
#     -0.03834608569741249,
#     -0.07850109040737152,
#     0.09522291272878647,
#     0.11647668480873108,
#     0.010908923111855984,
#     0.02463385835289955,
#     0.031449027359485626,
#     0.0690491646528244,
#     -0.04551102966070175,
#     0.022202739492058754,
#     -0.017978176474571228,
#     -0.021907668560743332,
#     0.0736854299902916,
#     0.038719575852155685,
#     -0.13642898201942444,
#     0.0528763085603714,
#     0.068053238093853,
#     -0.044973958283662796,
#     -0.002649764996021986,
#     -0.03699479252099991,
#     0.08165153861045837,
#     0.008094611577689648,
#     0.038139406591653824,
#     -0.03794623166322708,
#     0.07755624502897263,
#     0.021500293165445328,
#     -0.055114444345235825,
#     -0.08005112409591675,
#     0.018272768706083298,
#     0.06967869400978088,
#     -0.00011091113992733881,
#     0.02349121868610382,
#     -0.011606656946241856,
#     0.010649239644408226,
#     0.09175951033830643,
#     0.02580222487449646,
#     -0.033240363001823425,
#     -0.03555971756577492,
#     0.03296447917819023,
#     0.002895900048315525,
#     0.0802806168794632,
#     0.0456480048596859,
#     0.01592635177075863,
#     0.07473379373550415,
#     0.06195463240146637,
#     -0.012897935695946217,
#     0.025350265204906464,
#     0.02545139007270336,
#     0.0744583010673523,
#     0.0023720567114651203,
#     -0.014452246949076653,
#     0.01525962445884943]}}]

# %%
qr ={ 
    "query":{
        "match":{
            "document":"customer",
        }
}}

# %%
client.search(index = "dp_test_1", body = qr)["hits"]["hits"]
# Out:
# [{'_index': 'dp_test_1',
#   '_id': 'hxyiQI4B8m6BE82W_4Uy',
#   '_score': 0.5772112,
#   '_source': {'title': 'Customer_360',
#    'owner': 'Ishmin Singh',
#    'tier': 'Gold',
#    'version': 'v1.1',
#    'version_date': 'July 17, 2023 13:00',
#    'description': 'Customer data from various sources, enabling a holistic view of customers. ',
#    'tags': ['marketing', 'customer.360'],
#    'Health': {'quality_score': '70%', 'operational_health': '70%'},
#    'governance': {'access_policies': 3, 'data_policies': 3},
#    'stacks': ['flare', 'benthos', 'alpha'],
#    'document': 'What is it?\nThe Customer 360 is a tool designed to create a comprehensive view of customers by combining data from multiple sources. It includes information centered around a customer and further associated details of stores, products, and transaction details. \n\nWhat does it solve? \nCustomer 360 addresses the challenge of aggregating and analyzing customer-related data from disparate sources. By consolidating data into a unified format, it enables users to gain valuable insights into customer behavior, purchase patterns, and preferences. This comprehensive view empowers teams to make data-driven decisions. \nUse Cases \n• Customer Analytics: Businesses can gain insights into customer behavior, identify high-value customers, and personalize marketing strategies. \n• Inventory Management: By understanding product preferences and demand patterns, companies can optimize their inventory and restocking processes.\n• Fraud Detection: Analyzing customer orders and transaction data can help identify suspicious activities or potential fraud.\n• Personalization Opportunities: By understanding individual customer preferences and purchase habits, businesses can personalize marketing efforts, promotions, and product recommendations, enhancing customer satisfaction and loyalty. \n• Demand and Inventory Insights: Analyzing purchase patterns can provide valuable insights into demand for specific products or services, enabling businesses to optimize inventory management and restocking strategies. \n• Event-Driven Marketing: Businesses can leverage streaming data to trigger event-driven marketing campaigns. For example, sending personalized offers or promotions based on specific customer actions, such as completing a large purchase. \n\nKey Features \n• Advanced analytics\n Built with \n\nWhat libraries and frameworks does it use? \n• Python: For data processing, transformation, and integration tasks. \nApache Kafka: To enable real-time streaming of customer order events. \nApache Spark: For handling large-scale data processing efficiently. \nPostgreSQL: As the primary database to store the enriched order data. ',
#    'data_sources': [{'title': 'customers',
#      'description': 'Contains customer information, including customer_index, name, contact details, and other relevant attributes. '},
#     {'title': 'stores',
#      'description': 'Provides data about various stores, including store_index, location, and store attributes.'},
#     {'title': 'products',
#      'description': 'Contains details of different products, including product_index, name, description, and product attributes. '},
#     {'title': 'transactions',
#      'description': 'Holds transaction data, including transaction_index, transaction_date, transaction_line_item, and transaction details.'}]}}]

# %%
# semantic_qr= {
#   "_source": {
#     "excludes": ["title_vec", "description_vec"]
#   },
#   "query": {
#     "neural": {
#       "title_vec": {
#         "query_text":"banking",
#         "k": 10
#       }
#     }
#   }
# }

# %%
client.search(index="dp_test_1", body=semantic_qr)["hits"]["hits"]
# client.search(index = "dp_test_1", body = qr)["hits"]["hits"]
# Out:
# ---------------------------------------------------------------------------
# TransportError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 client.search(index="dp_test_1", body=semantic_qr)["hits"]["hits"]
#
# File ~/anaconda3/lib/python3.9/site-packages/opensearchpy/client/utils.py:181, in query_params.<locals>._wrapper.<locals>._wrapped(*args, **kwargs)
#     178         if v is not None:
#     179             params[p] = _escape(v)
# --> 181 return func(*args, params=params, headers=headers, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/opensearchpy/client/__init__.py:1742, in OpenSearch.search(self, body, index, params, headers)
#    1739 if "from_" in params:
#    1740     params["from"] = params.pop("from_")
# -> 1742 return self.transport.perform_request(
#    1743     "POST",
#    1744     _make_path(index, "_search"),
#    1745     params=params,
#    1746     headers=headers,
#    1747     body=body,
#    1748 )
#
# File ~/anaconda3/lib/python3.9/site-packages/opensearchpy/transport.py:448, in Transport.perform_request(self, method, url, params, body, timeout, ignore, headers)
#     446             raise e
#     447     else:
# --> 448         raise e
#     450 else:
#     451     # connection didn't fail, confirm its live status
#     452     self.connection_pool.mark_live(connection)
#
# File ~/anaconda3/lib/python3.9/site-packages/opensearchpy/transport.py:409, in Transport.perform_request(self, method, url, params, body, timeout, ignore, headers)
#     406 connection = self.get_connection()
#     408 try:
# --> 409     status, headers_response, data = connection.perform_request(
#     410         method,
#     411         url,
#     412         params,
#     413         body,
#     414         headers=headers,
#     415         ignore=ignore,
#     416         timeout=timeout,
#     417     )
#     419     # Lowercase all the header names for consistency in accessing them.
#     420     headers_response = {
#     421         header.lower(): value for header, value in headers_response.items()
#     422     }
#
# File ~/anaconda3/lib/python3.9/site-packages/opensearchpy/connection/http_urllib3.py:290, in Urllib3HttpConnection.perform_request(self, method, url, params, body, timeout, ignore, headers)
#     286 if not (200 <= response.status < 300) and response.status not in ignore:
#     287     self.log_request_fail(
#     288         method, full_url, url, orig_body, duration, response.status, raw_data
#     289     )
# --> 290     self._raise_error(
#     291         response.status,
#     292         raw_data,
#     293         self.get_response_headers(response).get("content-type"),
#     294     )
#     296 self.log_request_success(
#     297     method, full_url, url, orig_body, response.status, raw_data, duration
#     298 )
#     300 return response.status, response.headers, raw_data
#
# File ~/anaconda3/lib/python3.9/site-packages/opensearchpy/connection/base.py:316, in Connection._raise_error(self, status_code, raw_data, content_type)
#     313 except (ValueError, TypeError) as err:
#     314     logger.warning("Undecodable raw error response from server: %s", err)
# --> 316 raise HTTP_EXCEPTIONS.get(status_code, TransportError)(
#     317     status_code, error_message, additional_info
#     318 )
#
# TransportError: TransportError(500, 'null_pointer_exception', 'modelId is marked non-null but is null')

# %%
search_query = {
    "query": {
        "match": {
            "title": input("Enter your search text: ")
        }
    },
    "size": 10  
}
# Out:
# Enter your search text: health

# %%
response = client.search(index="dp_test_1", body=search_query)

# %%
total_hits = response["hits"]["total"]["value"]
print("Total hits:", total_hits)
# Out:
# Total hits: 0

# %%
query = {
    "query": {
        "match": {
            "title": "customer"
        }
    }
}

# %%
response = client.search(index="dp_test_1", body=query)

# %%
hits = response["hits"]["hits"]

# Print the results
for hit in hits:
    print(hit["_source"])

# %%
total_hits = response["hits"]["total"]["value"]
print("Total hits:", total_hits)
# Out:
# Total hits: 0

# %%
import numpy as np

# %%
title_vec = np.array([doc['title_vec'], doc_fin['title_vec'], doc_hel['title_vec']])
description_vec = np.array([doc['description_vec'],doc_fin['description_vec'],doc_hel['description_vec']])

# %%
query = {
    "query": {
        "script_score": {
            "query": {"match_all": {}},
            "script": {
                "source": "cosineSimilarity(params.query_vector, doc['title_vec']) + cosineSimilarity(params.query_vector, doc['description_vec'])",
                "params": {"query_vector": title_vec + description_vec}  # combining title and description vectors
            }
        }
    }
}

# %%
result = client.search(index="dp_test_1", body=query)
# Out:
# ---------------------------------------------------------------------------
# RequestError                              Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 result = client.search(index="dp_test_1", body=query)
#
# File ~/anaconda3/lib/python3.9/site-packages/opensearchpy/client/utils.py:181, in query_params.<locals>._wrapper.<locals>._wrapped(*args, **kwargs)
#     178         if v is not None:
#     179             params[p] = _escape(v)
# --> 181 return func(*args, params=params, headers=headers, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/opensearchpy/client/__init__.py:1742, in OpenSearch.search(self, body, index, params, headers)
#    1739 if "from_" in params:
#    1740     params["from"] = params.pop("from_")
# -> 1742 return self.transport.perform_request(
#    1743     "POST",
#    1744     _make_path(index, "_search"),
#    1745     params=params,
#    1746     headers=headers,
#    1747     body=body,
#    1748 )
#
# File ~/anaconda3/lib/python3.9/site-packages/opensearchpy/transport.py:448, in Transport.perform_request(self, method, url, params, body, timeout, ignore, headers)
#     446             raise e
#     447     else:
# --> 448         raise e
#     450 else:
#     451     # connection didn't fail, confirm its live status
#     452     self.connection_pool.mark_live(connection)
#
# File ~/anaconda3/lib/python3.9/site-packages/opensearchpy/transport.py:409, in Transport.perform_request(self, method, url, params, body, timeout, ignore, headers)
#     406 connection = self.get_connection()
#     408 try:
# --> 409     status, headers_response, data = connection.perform_request(
#     410         method,
#     411         url,
#     412         params,
#     413         body,
#     414         headers=headers,
#     415         ignore=ignore,
#     416         timeout=timeout,
#     417     )
#     419     # Lowercase all the header names for consistency in accessing them.
#     420     headers_response = {
#     421         header.lower(): value for header, value in headers_response.items()
#     422     }
#
# File ~/anaconda3/lib/python3.9/site-packages/opensearchpy/connection/http_urllib3.py:290, in Urllib3HttpConnection.perform_request(self, method, url, params, body, timeout, ignore, headers)
#     286 if not (200 <= response.status < 300) and response.status not in ignore:
#     287     self.log_request_fail(
#     288         method, full_url, url, orig_body, duration, response.status, raw_data
#     289     )
# --> 290     self._raise_error(
#     291         response.status,
#     292         raw_data,
#     293         self.get_response_headers(response).get("content-type"),
#     294     )
#     296 self.log_request_success(
#     297     method, full_url, url, orig_body, response.status, raw_data, duration
#     298 )
#     300 return response.status, response.headers, raw_data
#
# File ~/anaconda3/lib/python3.9/site-packages/opensearchpy/connection/base.py:316, in Connection._raise_error(self, status_code, raw_data, content_type)
#     313 except (ValueError, TypeError) as err:
#     314     logger.warning("Undecodable raw error response from server: %s", err)
# --> 316 raise HTTP_EXCEPTIONS.get(status_code, TransportError)(
#     317     status_code, error_message, additional_info
#     318 )
#
# RequestError: RequestError(400, 'search_phase_execution_exception', "class_cast_exception: class org.opensearch.index.fielddata.ScriptDocValues$Doubles cannot be cast to class org.opensearch.knn.index.KNNVectorScriptDocValues (org.opensearch.index.fielddata.ScriptDocValues$Doubles is in unnamed module of loader 'app'; org.opensearch.knn.index.KNNVectorScriptDocValues is in unnamed module of loader java.net.FactoryURLClassLoader @1235151c)")

# %%
search_query = {
    "_source": {
        "excludes": [
            "passage_embedding"
        ]
    },
    "query": {
        "bool": {
            "filter": {
                "wildcard": {
                }
            },
            "should": [
                {
                    "script_score": {
                        "query": {
                            "neural": {
                                "passage_embedding": {
                                    "query_text": input("Enter your search text: "),
                                    "model_id": "Your model ID",
                                    "k": 100
                                }
                            }
                        },
                        "script": {
                            "source": "_score * 1.5"
                        }
                    }
                },
                {
                    "script_score": {
                        "query": {
                            "match": {
                            }
                        },
                        "script": {
                            "source": "_score * 1.7"
                        }
                    }
                }
            ]
        }
    }
}
# Out:
# Enter your search text: customer

# %%
result = client.search(index="dp_test_1", body=search_query)
# Out:
# ---------------------------------------------------------------------------
# RequestError                              Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 result = client.search(index="dp_test_1", body=search_query)
#
# File ~/anaconda3/lib/python3.9/site-packages/opensearchpy/client/utils.py:181, in query_params.<locals>._wrapper.<locals>._wrapped(*args, **kwargs)
#     178         if v is not None:
#     179             params[p] = _escape(v)
# --> 181 return func(*args, params=params, headers=headers, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/opensearchpy/client/__init__.py:1742, in OpenSearch.search(self, body, index, params, headers)
#    1739 if "from_" in params:
#    1740     params["from"] = params.pop("from_")
# -> 1742 return self.transport.perform_request(
#    1743     "POST",
#    1744     _make_path(index, "_search"),
#    1745     params=params,
#    1746     headers=headers,
#    1747     body=body,
#    1748 )
#
# File ~/anaconda3/lib/python3.9/site-packages/opensearchpy/transport.py:448, in Transport.perform_request(self, method, url, params, body, timeout, ignore, headers)
#     446             raise e
#     447     else:
# --> 448         raise e
#     450 else:
#     451     # connection didn't fail, confirm its live status
#     452     self.connection_pool.mark_live(connection)
#
# File ~/anaconda3/lib/python3.9/site-packages/opensearchpy/transport.py:409, in Transport.perform_request(self, method, url, params, body, timeout, ignore, headers)
#     406 connection = self.get_connection()
#     408 try:
# --> 409     status, headers_response, data = connection.perform_request(
#     410         method,
#     411         url,
#     412         params,
#     413         body,
#     414         headers=headers,
#     415         ignore=ignore,
#     416         timeout=timeout,
#     417     )
#     419     # Lowercase all the header names for consistency in accessing them.
#     420     headers_response = {
#     421         header.lower(): value for header, value in headers_response.items()
#     422     }
#
# File ~/anaconda3/lib/python3.9/site-packages/opensearchpy/connection/http_urllib3.py:290, in Urllib3HttpConnection.perform_request(self, method, url, params, body, timeout, ignore, headers)
#     286 if not (200 <= response.status < 300) and response.status not in ignore:
#     287     self.log_request_fail(
#     288         method, full_url, url, orig_body, duration, response.status, raw_data
#     289     )
# --> 290     self._raise_error(
#     291         response.status,
#     292         raw_data,
#     293         self.get_response_headers(response).get("content-type"),
#     294     )
#     296 self.log_request_success(
#     297     method, full_url, url, orig_body, response.status, raw_data, duration
#     298 )
#     300 return response.status, response.headers, raw_data
#
# File ~/anaconda3/lib/python3.9/site-packages/opensearchpy/connection/base.py:316, in Connection._raise_error(self, status_code, raw_data, content_type)
#     313 except (ValueError, TypeError) as err:
#     314     logger.warning("Undecodable raw error response from server: %s", err)
# --> 316 raise HTTP_EXCEPTIONS.get(status_code, TransportError)(
#     317     status_code, error_message, additional_info
#     318 )
#
# RequestError: RequestError(400, 'x_content_parse_exception', '[1:86] [bool] failed to parse field [filter]')
